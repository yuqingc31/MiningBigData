# %% [markdown]
# ## 1. Read the dataset

# %%
import pandas as pd

train_data_original = pd.read_csv("basket_data_by_date_train.csv")
test_data_original = pd.read_csv("basket_data_by_date_test.csv")

# %% [markdown]
# Check the structure and content of the dataset

# %%
print("Train Data Info:")
print(train_data_original.info())

print("\nTest Data Info:")
print(test_data_original.info())
# Out:
# Train Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BillNo      40000 non-null  int64
#  1   Itemname    40000 non-null  object
#  2   Quantity    40000 non-null  int64
#  3   Date        40000 non-null  object
#  4   Price       40000 non-null  float64
#  5   CustomerID  40000 non-null  int64
#  6   cost        40000 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 2.1+ MB
# None
#
# Test Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BillNo      10000 non-null  float64
#  1   Itemname    10000 non-null  object
#  2   Quantity    10000 non-null  float64
#  3   Date        10000 non-null  object
#  4   Price       10000 non-null  float64
#  5   CustomerID  10000 non-null  float64
#  6   cost        10000 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 2.1+ MB
# None

# %%
test_data_original.describe()
# Out:
#               BillNo      Quantity         Price    CustomerID          cost
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean   545209.692000      3.672100      3.971454  15433.082900     11.840678
# std       492.638789      2.639788      6.777596   1616.660727     13.086198
# min    544398.000000      1.000000      0.160000  12352.000000      0.190000
# 25%    544795.000000      2.000000      1.650000  14227.000000      3.750000
# 50%    545181.000000      3.000000      2.950000  15358.000000      9.900000
# 75%    545664.000000      6.000000      4.950000  16931.000000     16.500000
# max    546084.000000     10.000000    195.000000  18283.000000    290.000000

# %%
train_data_original.describe()
# Out:
#               BillNo      Quantity         Price    CustomerID          cost
# count   40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean   540254.879225      3.487700      3.732165  15577.606525     11.097411
# std      2380.444952      2.611766      5.711630   1730.347123     13.298301
# min    536365.000000      1.000000      0.100000  12347.000000      0.140000
# 25%    538093.000000      1.000000      1.650000  14224.000000      3.300000
# 50%    540373.000000      2.000000      2.950000  15570.000000      7.950000
# 75%    542360.000000      6.000000      4.650000  17220.000000     15.800000
# max    544398.000000     10.000000    295.000000  18283.000000    527.700000

# %% [markdown]
# ## 2. Pre-process the data

# %% [markdown]
# #### 2.1 Clean the missing value

# %%
# check if there are missing values in the train set
print("Train Data Missing Values:")
print(train_data_original.isnull().sum())

# check if there are missing values in the test set
print("\nTest Data Missing Values:")
print(test_data_original.isnull().sum())
# Out:
# Train Data Missing Values:
# BillNo        0
# Itemname      0
# Quantity      0
# Date          0
# Price         0
# CustomerID    0
# cost          0
# dtype: int64
#
# Test Data Missing Values:
# BillNo        30000
# Itemname      30000
# Quantity      30000
# Date          30000
# Price         30000
# CustomerID    30000
# cost          30000
# dtype: int64

# %%
test_data_clean = test_data_original

# %%
# 删除从第10001行开始的缺失值
test_data_clean = test_data_original.iloc[:10000]

# 检查删除缺失值后的数据集大小
print("The size after cleaned the missing values", test_data_clean.shape)
# Out:
# The size after cleaned the missing values (10000, 7)

# %%
test_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BillNo      10000 non-null  float64
#  1   Itemname    10000 non-null  object
#  2   Quantity    10000 non-null  float64
#  3   Date        10000 non-null  object
#  4   Price       10000 non-null  float64
#  5   CustomerID  10000 non-null  float64
#  6   cost        10000 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 547.0+ KB

# %% [markdown]
# #### 2.2 Remove not related columns

# %%
# delete unrelated columns
train_data_drop = train_data_original.drop(columns=['BillNo', 'Date', 'Price', 'cost'])
test_data = test_data_clean.drop(columns=['BillNo', 'Date', 'Price', 'cost'])

# %%
train_data_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Itemname    40000 non-null  object
#  1   Quantity    40000 non-null  int64
#  2   CustomerID  40000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 937.6+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Itemname    10000 non-null  object
#  1   Quantity    10000 non-null  float64
#  2   CustomerID  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %% [markdown]
# ## 新添加：需要找出test和training中没有交集的customerID和itemname，并且把他们给drop掉

# %% [markdown]
# traindata太长了所以要缩短

# %%
train_data = train_data_drop

# %%
import pandas as pd

# 找到测试数据和训练数据中共同出现的商品名称和顾客ID
common_item_names = set(test_data['Itemname']).intersection(set(train_data['Itemname']))
common_customer_ids = set(test_data['CustomerID']).intersection(set(train_data['CustomerID']))

test_data = test_data[test_data['Itemname'].isin(common_item_names)]
test_data = test_data[test_data['CustomerID'].isin(common_customer_ids)]

train_data = train_data[train_data['Itemname'].isin(common_item_names)]
train_data = train_data[train_data['CustomerID'].isin(common_customer_ids)]

# %%
# 找出train_data中存在但test_data中不存在的商品名称和顾客ID
train_item_names = set(train_data['Itemname'])
train_customer_ids = set(train_data['CustomerID'])

extra_item_names_train = train_item_names - common_item_names
extra_customer_ids_train = train_customer_ids - common_customer_ids

# 找出test_data中存在但train_data中不存在的商品名称和顾客ID
test_item_names = set(test_data['Itemname'])
test_customer_ids = set(test_data['CustomerID'])

extra_item_names_test = test_item_names - common_item_names
extra_customer_ids_test = test_customer_ids - common_customer_ids

print("Train data中存在但test data中不存在的商品名称:", extra_item_names_train)
print("Train data中存在但test data中不存在的顾客ID:", extra_customer_ids_train)

print("Test data中存在但train data中不存在的商品名称:", extra_item_names_test)
print("Test data中存在但train data中不存在的顾客ID:", extra_customer_ids_test)
# Out:
# Train data中存在但test data中不存在的商品名称: set()
# Train data中存在但test data中不存在的顾客ID: set()
# Test data中存在但train data中不存在的商品名称: set()
# Test data中存在但train data中不存在的顾客ID: set()

# %% [markdown]
# #### 2.3 customer-item matrix
#
# Now I will convert the data into the form of customer-item matrix

# %%
len(train_data.CustomerID.unique()), len(train_data.Itemname.unique())
# Out:
# (248, 1397)

# %%
import pandas as pd

# 使用 pivot_table 构建用户-商品矩阵
user_item_matrix = pd.pivot_table(train_data, index='CustomerID', columns='Itemname', aggfunc=len, fill_value=0)

# 打印用户-商品矩阵
user_item_matrix
# Out:
#                          Quantity                             \
# Itemname   10 COLOUR SPACEBOY PEN 12 COLOURED PARTY BALLOONS
# CustomerID
# 12352                           0                          0
# 12415                           0                          0
# 12417                           0                          0
# 12423                           0                          0
# 12431                           0                          0
# ...                           ...                        ...
# 18075                           0                          0
# 18118                           0                          0
# 18198                           0                          0
# 18223                           0                          0
# 18283                           0                          0
#
#                                                                 \
# Itemname   12 DAISY PEGS IN WOOD BOX 12 EGG HOUSE PAINTED WOOD
# CustomerID
# 12352                              0                         0
# 12415                              0                         0
# 12417                              0                         0
# 12423                              0                         0
# 12431                              0                         0
# ...                              ...                       ...
# 18075                              0                         0
# 18118                              0                         0
# 18198                              0                         0
# 18223                              0                         0
# 18283                              0                         0
#
#                                                                              \
# Itemname   12 IVORY ROSE PEG PLACE SETTINGS 12 MESSAGE CARDS WITH ENVELOPES
# CustomerID
# 12352                                     0                               0
# 12415                                     0                               0
# 12417                                     0                               0
# 12423                                     0                               0
# 12431                                     0                               0
# ...                                     ...                             ...
# 18075                                     0                               0
# 18118                                     2                               1
# 18198                                     0                               0
# 18223                                     0                               0
# 18283                                     0                               0
#
#                                                                               \
# Itemname   12 PENCIL SMALL TUBE WOODLAND 12 PENCILS SMALL TUBE RED RETROSPOT
# CustomerID
# 12352                                  0                                   0
# 12415                                  0                                   0
# 12417                                  0                                   0
# 12423                                  0                                   0
# 12431                                  0                                   0
# ...                                  ...                                 ...
# 18075                                  0                                   0
# 18118                                  2                                   1
# 18198                                  0                                   0
# 18223                                  0                                   0
# 18283                                  0                                   0
#
#                                                                            \
# Itemname   12 PENCILS SMALL TUBE SKULL 12 PENCILS TALL TUBE RED RETROSPOT
# CustomerID
# 12352                                0                                  0
# 12415                                0                                  0
# 12417                                0                                  0
# 12423                                0                                  0
# 12431                                0                                  0
# ...                                ...                                ...
# 18075                                0                                  0
# 18118                                1                                  0
# 18198                                0                                  0
# 18223                                0                                  0
# 18283                                0                                  0
#
#             ...                                  \
# Itemname    ... YELLOW FLOWERS FELT HANDBAG KIT
# CustomerID  ...
# 12352       ...                               0
# 12415       ...                               0
# 12417       ...                               0
# 12423       ...                               0
# 12431       ...                               0
# ...         ...                             ...
# 18075       ...                               0
# 18118       ...                               2
# 18198       ...                               0
# 18223       ...                               0
# 18283       ...                               0
#
#                                                                        \
# Itemname   YELLOW GIANT GARDEN THERMOMETER YELLOW METAL CHICKEN HEART
# CustomerID
# 12352                                    0                          0
# 12415                                    0                          0
# 12417                                    0                          0
# 12423                                    0                          0
# 12431                                    0                          0
# ...                                    ...                        ...
# 18075                                    0                          0
# 18118                                    0                          0
# 18198                                    0                          0
# 18223                                    0                          0
# 18283                                    0                          0
#
#                                                                    \
# Itemname   YELLOW SHARK HELICOPTER YOU'RE CONFUSING ME METAL SIGN
# CustomerID
# 12352                            0                              0
# 12415                            0                              0
# 12417                            0                              0
# 12423                            0                              0
# 12431                            0                              0
# ...                            ...                            ...
# 18075                            0                              0
# 18118                            0                              0
# 18198                            0                              0
# 18223                            0                              0
# 18283                            0                              0
#
#                                                                            \
# Itemname   ZINC FINISH 15CM PLANTER POTS ZINC HEART LATTICE CHARGER LARGE
# CustomerID
# 12352                                  0                                0
# 12415                                  0                                0
# 12417                                  0                                0
# 12423                                  0                                0
# 12431                                  0                                0
# ...                                  ...                              ...
# 18075                                  0                                0
# 18118                                  1                                0
# 18198                                  0                                0
# 18223                                  0                                0
# 18283                                  0                                0
#
#                                                                           \
# Itemname   ZINC HEART LATTICE T-LIGHT HOLDER ZINC METAL HEART DECORATION
# CustomerID
# 12352                                      0                           0
# 12415                                      0                           0
# 12417                                      0                           0
# 12423                                      0                           0
# 12431                                      0                           0
# ...                                      ...                         ...
# 18075                                      0                           0
# 18118                                      0                           0
# 18198                                      0                           0
# 18223                                      0                           0
# 18283                                      0                           0
#
#
# Itemname   ZINC WILLIE WINKIE  CANDLE STICK
# CustomerID
# 12352                                     0
# 12415                                     0
# 12417                                     0
# 12423                                     0
# 12431                                     0
# ...                                     ...
# 18075                                     0
# 18118                                     0
# 18198                                     0
# 18223                                     0
# 18283                                     0
#
# [248 rows x 1397 columns]

# %% [markdown]
# ## 3. Calculate the similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# compute the cosine similarity matrix
user_similarity_matrix = cosine_similarity(user_item_matrix)

# convert the similarity matrix into a DataFrame
user_similarity_df = pd.DataFrame(user_similarity_matrix, index=user_item_matrix.index, columns=user_item_matrix.index)

print(user_similarity_df.iloc[:10, :7])
# Out:
# CustomerID     12352  12415     12417    12423     12431     12437     12464
# CustomerID
# 12352       1.000000    0.0  0.074536  0.00000  0.000000  0.000000  0.000000
# 12415       0.000000    1.0  0.000000  0.00000  0.000000  0.000000  0.000000
# 12417       0.074536    0.0  1.000000  0.00000  0.000000  0.000000  0.105409
# 12423       0.000000    0.0  0.000000  1.00000  0.081650  0.000000  0.000000
# 12431       0.000000    0.0  0.000000  0.08165  1.000000  0.000000  0.103280
# 12437       0.000000    0.0  0.000000  0.00000  0.000000  1.000000  0.000000
# 12464       0.000000    0.0  0.105409  0.00000  0.103280  0.000000  1.000000
# 12471       0.000000    0.0  0.030429  0.00000  0.000000  0.000000  0.057735
# 12474       0.000000    0.0  0.055556  0.00000  0.027217  0.000000  0.000000
# 12523       0.000000    0.0  0.000000  0.00000  0.000000  0.707107  0.000000

# %%
user_item_matrix = pd.pivot_table(train_data, index='CustomerID', columns='Itemname', aggfunc=len)
user_item_matrix
# Out:
#                          Quantity                             \
# Itemname   10 COLOUR SPACEBOY PEN 12 COLOURED PARTY BALLOONS
# CustomerID
# 12352                         NaN                        NaN
# 12415                         NaN                        NaN
# 12417                         NaN                        NaN
# 12423                         NaN                        NaN
# 12431                         NaN                        NaN
# ...                           ...                        ...
# 18075                         NaN                        NaN
# 18118                         NaN                        NaN
# 18198                         NaN                        NaN
# 18223                         NaN                        NaN
# 18283                         NaN                        NaN
#
#                                                                 \
# Itemname   12 DAISY PEGS IN WOOD BOX 12 EGG HOUSE PAINTED WOOD
# CustomerID
# 12352                            NaN                       NaN
# 12415                            NaN                       NaN
# 12417                            NaN                       NaN
# 12423                            NaN                       NaN
# 12431                            NaN                       NaN
# ...                              ...                       ...
# 18075                            NaN                       NaN
# 18118                            NaN                       NaN
# 18198                            NaN                       NaN
# 18223                            NaN                       NaN
# 18283                            NaN                       NaN
#
#                                                                              \
# Itemname   12 IVORY ROSE PEG PLACE SETTINGS 12 MESSAGE CARDS WITH ENVELOPES
# CustomerID
# 12352                                   NaN                             NaN
# 12415                                   NaN                             NaN
# 12417                                   NaN                             NaN
# 12423                                   NaN                             NaN
# 12431                                   NaN                             NaN
# ...                                     ...                             ...
# 18075                                   NaN                             NaN
# 18118                                   2.0                             1.0
# 18198                                   NaN                             NaN
# 18223                                   NaN                             NaN
# 18283                                   NaN                             NaN
#
#                                                                               \
# Itemname   12 PENCIL SMALL TUBE WOODLAND 12 PENCILS SMALL TUBE RED RETROSPOT
# CustomerID
# 12352                                NaN                                 NaN
# 12415                                NaN                                 NaN
# 12417                                NaN                                 NaN
# 12423                                NaN                                 NaN
# 12431                                NaN                                 NaN
# ...                                  ...                                 ...
# 18075                                NaN                                 NaN
# 18118                                2.0                                 1.0
# 18198                                NaN                                 NaN
# 18223                                NaN                                 NaN
# 18283                                NaN                                 NaN
#
#                                                                            \
# Itemname   12 PENCILS SMALL TUBE SKULL 12 PENCILS TALL TUBE RED RETROSPOT
# CustomerID
# 12352                              NaN                                NaN
# 12415                              NaN                                NaN
# 12417                              NaN                                NaN
# 12423                              NaN                                NaN
# 12431                              NaN                                NaN
# ...                                ...                                ...
# 18075                              NaN                                NaN
# 18118                              1.0                                NaN
# 18198                              NaN                                NaN
# 18223                              NaN                                NaN
# 18283                              NaN                                NaN
#
#             ...                                  \
# Itemname    ... YELLOW FLOWERS FELT HANDBAG KIT
# CustomerID  ...
# 12352       ...                             NaN
# 12415       ...                             NaN
# 12417       ...                             NaN
# 12423       ...                             NaN
# 12431       ...                             NaN
# ...         ...                             ...
# 18075       ...                             NaN
# 18118       ...                             2.0
# 18198       ...                             NaN
# 18223       ...                             NaN
# 18283       ...                             NaN
#
#                                                                        \
# Itemname   YELLOW GIANT GARDEN THERMOMETER YELLOW METAL CHICKEN HEART
# CustomerID
# 12352                                  NaN                        NaN
# 12415                                  NaN                        NaN
# 12417                                  NaN                        NaN
# 12423                                  NaN                        NaN
# 12431                                  NaN                        NaN
# ...                                    ...                        ...
# 18075                                  NaN                        NaN
# 18118                                  NaN                        NaN
# 18198                                  NaN                        NaN
# 18223                                  NaN                        NaN
# 18283                                  NaN                        NaN
#
#                                                                    \
# Itemname   YELLOW SHARK HELICOPTER YOU'RE CONFUSING ME METAL SIGN
# CustomerID
# 12352                          NaN                            NaN
# 12415                          NaN                            NaN
# 12417                          NaN                            NaN
# 12423                          NaN                            NaN
# 12431                          NaN                            NaN
# ...                            ...                            ...
# 18075                          NaN                            NaN
# 18118                          NaN                            NaN
# 18198                          NaN                            NaN
# 18223                          NaN                            NaN
# 18283                          NaN                            NaN
#
#                                                                            \
# Itemname   ZINC FINISH 15CM PLANTER POTS ZINC HEART LATTICE CHARGER LARGE
# CustomerID
# 12352                                NaN                              NaN
# 12415                                NaN                              NaN
# 12417                                NaN                              NaN
# 12423                                NaN                              NaN
# 12431                                NaN                              NaN
# ...                                  ...                              ...
# 18075                                NaN                              NaN
# 18118                                1.0                              NaN
# 18198                                NaN                              NaN
# 18223                                NaN                              NaN
# 18283                                NaN                              NaN
#
#                                                                           \
# Itemname   ZINC HEART LATTICE T-LIGHT HOLDER ZINC METAL HEART DECORATION
# CustomerID
# 12352                                    NaN                         NaN
# 12415                                    NaN                         NaN
# 12417                                    NaN                         NaN
# 12423                                    NaN                         NaN
# 12431                                    NaN                         NaN
# ...                                      ...                         ...
# 18075                                    NaN                         NaN
# 18118                                    NaN                         NaN
# 18198                                    NaN                         NaN
# 18223                                    NaN                         NaN
# 18283                                    NaN                         NaN
#
#
# Itemname   ZINC WILLIE WINKIE  CANDLE STICK
# CustomerID
# 12352                                   NaN
# 12415                                   NaN
# 12417                                   NaN
# 12423                                   NaN
# 12431                                   NaN
# ...                                     ...
# 18075                                   NaN
# 18118                                   NaN
# 18198                                   NaN
# 18223                                   NaN
# 18283                                   NaN
#
# [248 rows x 1397 columns]

# %% [markdown]
# ## 4. Methods for making recommendation

# %% [markdown]
# #### 4.1 get the top similar customers
# Here we will use the number of purchases made by the customer as a rating, the more purchases made, the higher the rating.

# %%
def top_similar_users(user_similarity_matrix, user_id, n):
    similar_users = user_similarity_matrix.loc[user_id]
    
    # get the index of the top n similar users
    top_n_similar_users = similar_users.sort_values(ascending=False).iloc[1:n+1].index
    return top_n_similar_users

# %% [markdown]
# #### 4.2 predict the rating for each product
# For each item not rated by the target user, the rating is predicted by calculating the weighted average of the ratings given by the most similar users, where the weight is the similarity between the user and the target user.

# %%
def predict_user_based(user_item_matrix, user_similarity_matrix, user_id, item_id):
    # get the top 20 similar users
    top_sim_users = top_similar_users(user_similarity_matrix, user_id, 20)
    
    user_ratings = user_item_matrix.loc[user_id]
    
    mean_rating = user_ratings.mean()
    
    # compute the predicted rating
    pred_rating = 0
    sim_sum = 0
    
    for other_user in top_sim_users:
        other_user_rating = user_item_matrix.loc[other_user, item_id]
        if other_user_rating > 0:
            other_user_mean = user_item_matrix.loc[other_user].mean()
            sim_user = user_similarity_matrix.loc[user_id, other_user]
            pred_rating += sim_user * (other_user_rating - other_user_mean)
            sim_sum += sim_user
    
    if sim_sum > 0:
        pred_rating = mean_rating + pred_rating / sim_sum
    else:
        pred_rating = mean_rating
    
    return pred_rating

# %% [markdown]
# #### 4.3 Recommends the top N items with the highest predictive scores

# %%
def recommend_top_n_items(train_user_item_matrix, user_similarity_matrix, test_set, N):
    recommendations = pd.DataFrame(index=test_set.index, columns=['Top_Items'])
    
    # 使用训练集中的用户项目矩阵和用户相似性矩阵
    for user_id in test_set.index:
        # 获取该用户在训练集中尚未评分的物品
        unrated_items = train_user_item_matrix.loc[user_id][train_user_item_matrix.loc[user_id] == 0].index
        
        user_predictions = {}
        for item_id in unrated_items:
            user_predictions[item_id] = predict_user_based(train_user_item_matrix, user_similarity_matrix, user_id, item_id)
        
        # 按预测评分排序
        sorted_predictions = sorted(user_predictions.items(), key=lambda x: x[1], reverse=True)
        
        # 获取前 N 个物品
        top_n_items = [item[0] for item in sorted_predictions[:N]]
        
        recommendations.loc[user_id, 'Top_Items'] = top_n_items
    
    return recommendations

# %% [markdown]
# ## 6. Five recommended examples of what users actually buy

# %%
print(user_item_matrix.index)  # 打印 DataFrame df 的索引值
print(user_similarity_df.index)  # 打印 Series series 的索引值
user_item_matrix.index.equals(user_similarity_df.index)
# Out:
# Index([12352, 12415, 12417, 12423, 12431, 12437, 12464, 12471, 12474, 12523,
#        ...
#        18041, 18044, 18055, 18061, 18065, 18075, 18118, 18198, 18223, 18283],
#       dtype='int64', name='CustomerID', length=248)
# Index([12352, 12415, 12417, 12423, 12431, 12437, 12464, 12471, 12474, 12523,
#        ...
#        18041, 18044, 18055, 18061, 18065, 18075, 18118, 18198, 18223, 18283],
#       dtype='int64', name='CustomerID', length=248)
# True

# %%
# 重新设置索引并删除第一个索引位置
user_item_matrix = user_item_matrix.reset_index(drop=True)
user_similarity_df = user_similarity_df.reset_index(drop=True)

# %%
test_recommendations = recommend_top_n_items(user_item_matrix, user_similarity_df, test_data, N=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 248 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2 copy.ipynb Cell 38 line 1
# ----> <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2%20copy.ipynb#Y251sZmlsZQ%3D%3D?line=0'>1</a> test_recommendations = recommend_top_n_items(user_item_matrix, user_similarity_df, test_data, N=20)
#
# /Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2 copy.ipynb Cell 38 line 7
#       <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2%20copy.ipynb#Y251sZmlsZQ%3D%3D?line=3'>4</a> # 使用训练集中的用户项目矩阵和用户相似性矩阵
#       <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2%20copy.ipynb#Y251sZmlsZQ%3D%3D?line=4'>5</a> for user_id in test_set.index:
#       <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2%20copy.ipynb#Y251sZmlsZQ%3D%3D?line=5'>6</a>     # 获取该用户在训练集中尚未评分的物品
# ----> <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2%20copy.ipynb#Y251sZmlsZQ%3D%3D?line=6'>7</a>     unrated_items = train_user_item_matrix.loc[user_id][train_user_item_matrix.loc[user_id] == 0].index
#       <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2%20copy.ipynb#Y251sZmlsZQ%3D%3D?line=8'>9</a>     user_predictions = {}
#      <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2%20copy.ipynb#Y251sZmlsZQ%3D%3D?line=9'>10</a>     for item_id in unrated_items:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:4295, in NDFrame.xs(self, key, axis, level, drop_level)
#    4293             new_index = index[loc]
#    4294 else:
# -> 4295     loc = index.get_loc(key)
#    4297     if isinstance(loc, np.ndarray):
#    4298         if loc.dtype == np.bool_:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 248

# %%
for user_id, row in test_recommendations.iterrows():
    print("Top 5 recommended items for user", user_id, ":", row['Top_Items'])
# Out:
# Top 5 recommended items for user 15311.0 : ['RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'RED RETROSPOT WASHBAG', 'JUMBO STORAGE BAG SUKI']
# Top 5 recommended items for user 12594.0 : ['BALLOON ART MAKE YOUR OWN FLOWERS', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG WOODLAND', 'SKULL SHOULDER BAG', 'CHARLOTTE BAG SUKI DESIGN']
# Top 5 recommended items for user 16401.0 : ['JUMBO STORAGE BAG SUKI', 'TRAVEL CARD WALLET KEEP CALM', 'TRAVEL CARD WALLET RETROSPOT', 'GRAND CHOCOLATECANDLE', 'HANGING HEN ON NEST DECORATION']
# Top 5 recommended items for user 16814.0 : ['FROSTED WHITE BASE', 'JUMBO BAG PINK POLKADOT', 'TRAVEL SEWING KIT', 'MAGIC DRAWING SLATE SPACEBOY', 'WATERING CAN GARDEN MARKER']
# Top 5 recommended items for user 16726.0 : ['TEA TIME OVEN GLOVE', 'TOILET METAL SIGN', 'LUNCH BAG SUKI  DESIGN', 'RIDGED GLASS T-LIGHT HOLDER', 'GRAND CHOCOLATECANDLE']
# Top 5 recommended items for user 16265.0 : ['DOORMAT RED RETROSPOT', 'HEN HOUSE W CHICK STANDING', 'BALLOON ART MAKE YOUR OWN FLOWERS', 'JUMBO BAG SPACEBOY DESIGN', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 16531.0 : ['BUTTON BOX', 'JUMBO  BAG BAROQUE BLACK WHITE', 'CHARLOTTE BAG PINK POLKADOT', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 16306.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'BALLOON WATER BOMB PACK OF 35', 'GRAND CHOCOLATECANDLE', '12 COLOURED PARTY BALLOONS', 'STRAWBERRY FAIRY CAKE TEAPOT']
# Top 5 recommended items for user 15465.0 : ['JUMBO BAG TOYS', 'SET OF 4 ENGLISH ROSE COASTERS', 'RETROSPOT PARTY BAG + STICKER SET', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO BAG PINK POLKADOT']
# Top 5 recommended items for user 13246.0 : ['SMALL POPCORN HOLDER', 'LUNCH BAG SUKI  DESIGN', 'LUNCH BAG DOLLY GIRL DESIGN', 'WATERING CAN GARDEN MARKER', 'SET OF 4 ENGLISH ROSE COASTERS']
# Top 5 recommended items for user 16746.0 : ['JUMBO STORAGE BAG SUKI', 'CHARLOTTE BAG SUKI DESIGN', 'LUNCH BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'WATERING CAN GARDEN MARKER']
# Top 5 recommended items for user 14878.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'STRAWBERRY   PICNIC BAG', 'SMALL POPCORN HOLDER']
# Top 5 recommended items for user 17811.0 : ['TOY TIDY SPACEBOY', 'STRAWBERRY CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG', 'JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG OWLS']
# Top 5 recommended items for user 17214.0 : ['JUMBO BAG RED RETROSPOT', 'SET OF 4 ENGLISH ROSE COASTERS', 'GREEN METAL SWINGING BUNNY', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER']
# Top 5 recommended items for user 13097.0 : ['12 COLOURED PARTY BALLOONS', '6 ROCKET BALLOONS', 'LUNCH BAG SUKI  DESIGN', 'WOODLAND CHARLOTTE BAG', '12 PENCILS SMALL TUBE SKULL']
# Top 5 recommended items for user 14667.0 : ['CHARLOTTE BAG SUKI DESIGN', 'RED RETROSPOT CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 17838.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'JUMBO BAG SPACEBOY DESIGN', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 16931.0 : ['TRAVEL SEWING KIT', 'GENTLEMAN SHIRT REPAIR KIT', 'SEWING SUSAN 21 NEEDLE SET', 'LUNCH BAG SUKI  DESIGN', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 17050.0 : ['CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG DOLLY GIRL DESIGN', 'PARTY FOOD SHOPPER BAG', 'JUMBO BAG CHARLIE AND LOLA TOYS', 'STRAWBERRY SHOPPER BAG']
# Top 5 recommended items for user 13168.0 : ['JUMBO BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY', 'FROSTED WHITE BASE', 'WOODLAND CHARLOTTE BAG', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 14606.0 : ['RED RETROSPOT CHARLOTTE BAG', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG STRAWBERRY', 'WATERING CAN GARDEN MARKER', 'MAGIC DRAWING SLATE SPACEBOY']
# Top 5 recommended items for user 14502.0 : ['WOODLAND CHARLOTTE BAG', 'FROSTED WHITE BASE', 'CUPCAKE LACE PAPER SET 6', 'GRAND CHOCOLATECANDLE', 'PINK FAIRY CAKE CHILDRENS APRON']
# Top 5 recommended items for user 14229.0 : ['S/6 WOODEN SKITTLES IN COTTON BAG', '12 PENCILS SMALL TUBE SKULL', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER', 'JUMBO BAG WOODLAND ANIMALS']
# Top 5 recommended items for user 12423.0 : ['TRAVEL SEWING KIT', 'BUTTON BOX', 'JUMBO STORAGE BAG SUKI', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 14796.0 : ['DOORMAT HEARTS', 'TOILET METAL SIGN', 'CHARLOTTE BAG PINK POLKADOT', 'RECYCLING BAG RETROSPOT', 'WALL TIDY RETROSPOT']
# Top 5 recommended items for user 14646.0 : ['WOODLAND CHARLOTTE BAG', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG OWLS', 'GREEN METAL SWINGING BUNNY', 'RECYCLING BAG RETROSPOT']
# Top 5 recommended items for user 16656.0 : ['12 COLOURED PARTY BALLOONS', '6 ROCKET BALLOONS', 'JUMBO BAG DOLLY GIRL DESIGN', 'GENTLEMAN SHIRT REPAIR KIT', '12 PENCILS SMALL TUBE SKULL']
# Top 5 recommended items for user 12524.0 : ['JUMBO BAG WOODLAND ANIMALS', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN', 'LUNCH BAG DOLLY GIRL DESIGN', 'RED RETROSPOT OVEN GLOVE']
# Top 5 recommended items for user 17757.0 : ['RIBBON REEL STRIPES DESIGN', 'FRENCH BLUE METAL DOOR SIGN 9', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER', 'STRAWBERRY BATH SPONGE']
# Top 5 recommended items for user 12766.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'JUMBO STORAGE BAG SKULLS', 'LUNCH BAG PINK POLKADOT']
# Top 5 recommended items for user 18055.0 : ['BALLOON ART MAKE YOUR OWN FLOWERS', 'TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 14639.0 : ['WOODLAND CHARLOTTE BAG', 'JUMBO BAG SPACEBOY DESIGN', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'RECYCLING BAG RETROSPOT', 'JUMBO BAG OWLS']
# Top 5 recommended items for user 12621.0 : ['JUMBO BAG SPACEBOY DESIGN', 'CHARLOTTE BAG DOLLY GIRL DESIGN', 'JUMBO BAG OWLS', 'TRADITIONAL KNITTING NANCY', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 12523.0 : ['JUMBO BAG PINK POLKADOT', 'TRAVEL SEWING KIT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'RED RETROSPOT OVEN GLOVE', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 17338.0 : ['6 ROCKET BALLOONS', 'RETROSPOT PARTY BAG + STICKER SET', 'GRAND CHOCOLATECANDLE', 'BLUE POLKADOT CUP', 'COLOUR GLASS T-LIGHT HOLDER HANGING']
# Top 5 recommended items for user 16775.0 : ['JUMBO STORAGE BAG SUKI', 'JUMBO BAG STRAWBERRY', 'WOODLAND CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN']
# Top 5 recommended items for user 18061.0 : ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG SPACEBOY DESIGN', 'JUMBO BAG OWLS', 'JUMBO BAG WOODLAND ANIMALS', 'JUMBO STORAGE BAG SUKI']
# Top 5 recommended items for user 16638.0 : ['DOORMAT RED RETROSPOT', 'JUMBO BAG PINK POLKADOT', 'RIBBON REEL LACE DESIGN', 'TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG']
# Top 5 recommended items for user 13767.0 : ['12 COLOURED PARTY BALLOONS', '6 ROCKET BALLOONS', 'LUNCH BAG DOLLY GIRL DESIGN', 'TRAVEL SEWING KIT', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 13862.0 : ['TEA TIME PARTY BUNTING', 'RED RETROSPOT CHARLOTTE BAG', 'BUTTON BOX', 'RIBBON REEL STRIPES DESIGN', 'RIBBON REEL LACE DESIGN']
# Top 5 recommended items for user 16912.0 : ['TRAVEL SEWING KIT', 'LUNCH BAG CARS BLUE', 'SET OF 4 ENGLISH ROSE COASTERS', 'LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG WOODLAND']
# Top 5 recommended items for user 17315.0 : ['CHARLOTTE BAG PINK POLKADOT', 'SET OF 4 ENGLISH ROSE COASTERS', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY']
# Top 5 recommended items for user 14688.0 : ['SMALL HEART MEASURING SPOONS', 'JUMBO STORAGE BAG SUKI', 'RIBBON REEL LACE DESIGN', 'TRAVEL SEWING KIT', 'CHARLOTTE BAG SUKI DESIGN']
# Top 5 recommended items for user 16843.0 : ['WOODLAND CHARLOTTE BAG', 'LUNCH BAG DOLLY GIRL DESIGN', 'BALLOON WATER BOMB PACK OF 35', '12 COLOURED PARTY BALLOONS', 'STRAWBERRY FAIRY CAKE TEAPOT']
# Top 5 recommended items for user 17075.0 : ['TEA TIME PARTY BUNTING', 'RED RETROSPOT CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'SMALL POPCORN HOLDER']
# Top 5 recommended items for user 14060.0 : ['TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG', 'BUTTON BOX', 'MAGIC DRAWING SLATE SPACEBOY', 'DAISY GARDEN MARKER']
# Top 5 recommended items for user 13113.0 : ['SET OF 4 ENGLISH ROSE COASTERS', 'LUNCH BAG SUKI  DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'LUNCH BAG PINK POLKADOT', 'MAGIC DRAWING SLATE SPACEBOY']
# Top 5 recommended items for user 15078.0 : ['JUMBO BAG PINK POLKADOT', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG WOODLAND', 'CHARLOTTE BAG SUKI DESIGN', 'LUNCH BAG CARS BLUE']
# Top 5 recommended items for user 16907.0 : ['LUNCH BAG PINK POLKADOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG SPACEBOY DESIGN', 'BALLOON WATER BOMB PACK OF 35', 'GRAND CHOCOLATECANDLE']
# Top 5 recommended items for user 17511.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'JUMBO STORAGE BAG SUKI', 'CHARLOTTE BAG SUKI DESIGN', 'JUMBO BAG PINK POLKADOT', 'S/6 WOODEN SKITTLES IN COTTON BAG']
# Top 5 recommended items for user 16161.0 : ['JUMBO BAG PINK VINTAGE PAISLEY', 'LUNCH BAG SUKI  DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO  BAG BAROQUE BLACK WHITE', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 16011.0 : ['SMALL POPCORN HOLDER', 'FRENCH BLUE METAL DOOR SIGN 9', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG OWLS', 'JUMBO BAG WOODLAND ANIMALS']
# Top 5 recommended items for user 17841.0 : ['JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG SUKI  DESIGN', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG DOLLY GIRL DESIGN', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 13077.0 : ['JUMBO BAG RED RETROSPOT', 'TRAVEL SEWING KIT', 'RETROSPOT PARTY BAG + STICKER SET', 'TEA TIME OVEN GLOVE', 'TEA BAG PLATE RED RETROSPOT']
# Top 5 recommended items for user 12748.0 : ['JUMBO BAG DOLLY GIRL DESIGN', 'SKULL SHOULDER BAG', 'LUNCH BAG SUKI  DESIGN', 'JUMBO BAG PINK VINTAGE PAISLEY', 'TRAVEL SEWING KIT']
# Top 5 recommended items for user 17706.0 : ['JUMBO BAG SCANDINAVIAN PAISLEY', 'LUNCH BAG SUKI  DESIGN', 'LUNCH BAG RED RETROSPOT', '12 PENCILS SMALL TUBE SKULL', 'WOODLAND CHARLOTTE BAG']
# Top 5 recommended items for user 18041.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'JUMBO STORAGE BAG SUKI', 'TOY TIDY SPACEBOY']
# Top 5 recommended items for user 17428.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'WOODLAND CHARLOTTE BAG', 'JUMBO STORAGE BAG SUKI', 'RED RETROSPOT CHARLOTTE BAG', 'BUTTON BOX']
# Top 5 recommended items for user 17135.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'SMALL HEART MEASURING SPOONS', 'JUMBO BAG OWLS']
# Top 5 recommended items for user 15605.0 : ['FROSTED WHITE BASE', 'WATERING CAN GARDEN MARKER', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER', 'RED RETROSPOT OVEN GLOVE']
# Top 5 recommended items for user 15373.0 : ['SET OF 4 ENGLISH ROSE COASTERS', 'TRAVEL SEWING KIT', 'LUNCH BAG DOLLY GIRL DESIGN', 'BUTTON BOX', 'LUNCH BAG PINK POLKADOT']
# Top 5 recommended items for user 16422.0 : ['HEN HOUSE W CHICK STANDING', 'LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SPACEBOY DESIGN', 'TRAVEL SEWING KIT', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 14978.0 : ['S/6 WOODEN SKITTLES IN COTTON BAG', 'TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG', 'RED RETROSPOT OVEN GLOVE', 'GRAND CHOCOLATECANDLE']
# Top 5 recommended items for user 13089.0 : ['JUMBO STORAGE BAG SUKI', 'JUMBO BAG DOLLY GIRL DESIGN', 'CHARLOTTE BAG SUKI DESIGN', 'LUNCH BAG SUKI  DESIGN', 'WATERING CAN GARDEN MARKER']
# Top 5 recommended items for user 13993.0 : ['DOORMAT HEARTS', 'SET OF 4 ENGLISH ROSE COASTERS', 'JUMBO BAG SPACEBOY DESIGN', 'BLUE POLKADOT BOWL', 'RED RETROSPOT BOWL']
# Top 5 recommended items for user 13854.0 : ['FRENCH BLUE METAL DOOR SIGN 2', 'FRENCH BLUE METAL DOOR SIGN 0', 'FRENCH BLUE METAL DOOR SIGN 4', 'FRENCH BLUE METAL DOOR SIGN 6', 'FRENCH BLUE METAL DOOR SIGN 5']
# Top 5 recommended items for user 15858.0 : ['LUNCH BAG SUKI  DESIGN', 'JUMBO BAG PINK POLKADOT', 'RIBBON REEL LACE DESIGN', 'TRAVEL SEWING KIT', 'LUNCH BAG  BLACK SKULL.']
# Top 5 recommended items for user 15687.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'JUMBO STORAGE BAG SUKI', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 16145.0 : ['RIBBON REEL STRIPES DESIGN', 'JUMBO BAG STRAWBERRY', 'JUMBO STORAGE BAG SKULLS', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 17504.0 : ['CHARLOTTE BAG PINK POLKADOT', 'SET OF 4 ENGLISH ROSE COASTERS', 'STRAWBERRY SHOPPER BAG', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 14562.0 : ['TEA TIME PARTY BUNTING', 'TRAVEL SEWING KIT', 'LUNCH BAG SUKI  DESIGN', 'SMALL POPCORN HOLDER', 'RIBBON REEL STRIPES DESIGN']
# Top 5 recommended items for user 12471.0 : ['JUMBO STORAGE BAG SUKI', 'CHARLOTTE BAG SUKI DESIGN', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'JUMBO BAG WOODLAND ANIMALS', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 17675.0 : ['LUNCH BAG CARS BLUE', 'TOY TIDY SPACEBOY', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY']
# Top 5 recommended items for user 15984.0 : ['HEN HOUSE W CHICK STANDING', 'TEA TIME PARTY BUNTING', 'TRAVEL SEWING KIT', 'LUNCH BAG SUKI  DESIGN', 'SMALL POPCORN HOLDER']
# Top 5 recommended items for user 12437.0 : ['RED RETROSPOT PEG BAG', 'TOY TIDY SPACEBOY', 'JUMBO BAG PINK POLKADOT', 'CHARLOTTE BAG PINK POLKADOT', 'SKULL SHOULDER BAG']
# Top 5 recommended items for user 12971.0 : ['STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'SKULL SHOULDER BAG', 'GENTLEMAN SHIRT REPAIR KIT', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 15606.0 : ['12 COLOURED PARTY BALLOONS', '6 ROCKET BALLOONS', 'BALLOON ART MAKE YOUR OWN FLOWERS', '12 PENCILS SMALL TUBE SKULL', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 17613.0 : ['12 PENCILS SMALL TUBE SKULL', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'GRAND CHOCOLATECANDLE', 'DOORMAT FANCY FONT HOME SWEET HOME', 'JUMBO BAG SPACEBOY DESIGN']
# Top 5 recommended items for user 15910.0 : ['TRAVEL CARD WALLET RETROSPOT', 'TRAVEL SEWING KIT', 'RED RETROSPOT OVEN GLOVE', 'GRAND CHOCOLATECANDLE', 'PACK OF 12 STICKY BUNNIES']
# Top 5 recommended items for user 14841.0 : ['CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG', 'LUNCH BAG SPACEBOY DESIGN', 'RED RETROSPOT SHOPPER BAG']
# Top 5 recommended items for user 16719.0 : ['JUMBO STORAGE BAG SKULLS', 'TRAVEL CARD WALLET KEEP CALM', 'TRAVEL CARD WALLET RETROSPOT', 'TRAVEL SEWING KIT', 'BUTTON BOX']
# Top 5 recommended items for user 16086.0 : ['EDWARDIAN PARASOL BLACK', 'CHARLOTTE BAG PINK POLKADOT', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'RED RETROSPOT WASHBAG']
# Top 5 recommended items for user 14243.0 : ['SET OF 4 ENGLISH ROSE COASTERS', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'BALLOON WATER BOMB PACK OF 35']
# Top 5 recommended items for user 17364.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'JUMBO BAG SPACEBOY DESIGN', 'FROSTED WHITE BASE', 'RED RETROSPOT OVEN GLOVE', 'BALLOON WATER BOMB PACK OF 35']
# Top 5 recommended items for user 14527.0 : ['TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG', 'BUTTON BOX', 'RECYCLING BAG RETROSPOT', 'TOY TIDY PINK POLKADOT']
# Top 5 recommended items for user 17865.0 : ['JUMBO BAG SPACEBOY DESIGN', 'LUNCH BAG DOLLY GIRL DESIGN', 'TRAVEL SEWING KIT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 15805.0 : ['SMALL HEART MEASURING SPOONS', 'LUNCH BAG SUKI  DESIGN', 'JUMBO STORAGE BAG SUKI', 'TOY TIDY SPACEBOY', 'SKULL SHOULDER BAG']
# Top 5 recommended items for user 14189.0 : ['JUMBO STORAGE BAG SUKI', '12 COLOURED PARTY BALLOONS', '6 ROCKET BALLOONS', 'LUNCH BAG SUKI  DESIGN', 'TRAVEL SEWING KIT']
# Top 5 recommended items for user 18065.0 : ['JUMBO BAG PINK POLKADOT', 'TRAVEL SEWING KIT', 'RED RETROSPOT OVEN GLOVE', 'LUNCH BAG PINK POLKADOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 13018.0 : ['JUMBO BAG PINK POLKADOT', 'RIBBON REEL LACE DESIGN', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG DOLLY GIRL DESIGN', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 17017.0 : ['JUMBO BAG RED RETROSPOT', 'EDWARDIAN PARASOL BLACK', 'RECYCLING BAG RETROSPOT', 'WALL TIDY RETROSPOT', 'CHILDS GARDEN FORK BLUE']
# Top 5 recommended items for user 14298.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'PIGGY BANK RETROSPOT', 'STRAWBERRY FAIRY CAKE TEAPOT', 'BAKING SET 9 PIECE RETROSPOT', 'BAKING MOULD CHOCOLATE CUPCAKES']
# Top 5 recommended items for user 18198.0 : ['BALLOON ART MAKE YOUR OWN FLOWERS', 'CHARLOTTE BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG OWLS']
# Top 5 recommended items for user 16722.0 : ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'WATERING CAN GARDEN MARKER', '12 PENCILS SMALL TUBE SKULL']
# Top 5 recommended items for user 17377.0 : ['TRAVEL SEWING KIT', 'SMALL POPCORN HOLDER', 'GRAND CHOCOLATECANDLE', 'HANGING HEN ON NEST DECORATION', 'CERAMIC STRAWBERRY DESIGN MUG']
# Top 5 recommended items for user 13081.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'LUNCH BAG  BLACK SKULL.', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 13725.0 : ['TRAVEL CARD WALLET KEEP CALM', 'TRAVEL CARD WALLET RETROSPOT', 'TRAVEL CARD WALLET VINTAGE ROSE', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO STORAGE BAG SUKI']
# Top 5 recommended items for user 13468.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG RED RETROSPOT']
# Top 5 recommended items for user 17472.0 : ['GREEN METAL SWINGING BUNNY', 'LUNCH BAG SUKI  DESIGN', 'MAGIC DRAWING SLATE SPACEBOY', '12 PENCILS SMALL TUBE SKULL', 'RIDGED GLASS T-LIGHT HOLDER']
# Top 5 recommended items for user 16133.0 : ['JUMBO BAG SPACEBOY DESIGN', 'FROSTED WHITE BASE', 'RIBBON REEL STRIPES DESIGN', 'LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 12839.0 : ['12 PENCILS SMALL TUBE SKULL', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'TRAVEL SEWING KIT', 'SET OF 4 ENGLISH ROSE COASTERS', 'LAVENDER SCENTED FABRIC HEART']
# Top 5 recommended items for user 12841.0 : ['RECYCLING BAG RETROSPOT', 'JUMBO BAG OWLS', 'RIBBON REEL STRIPES DESIGN', 'JUMBO BAG SPACEBOY DESIGN', 'GENTLEMAN SHIRT REPAIR KIT']
# Top 5 recommended items for user 15544.0 : ['JUMBO STORAGE BAG SKULLS', 'JUMBO BAG PINK POLKADOT', 'LUNCH BAG DOLLY GIRL DESIGN', 'JUMBO BAG STRAWBERRY', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 14541.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'JUMBO STORAGE BAG SUKI', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 17735.0 : ['DAISY GARDEN MARKER', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG SCANDINAVIAN PAISLEY', '12 PENCILS SMALL TUBE SKULL']
# Top 5 recommended items for user 13458.0 : ['TRAVEL SEWING KIT', 'BLUE POLKADOT BOWL', 'RED RETROSPOT BOWL', 'PINK POLKADOT BOWL', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 12474.0 : ['GENTLEMAN SHIRT REPAIR KIT', 'SEWING SUSAN 21 NEEDLE SET', 'GREEN METAL SWINGING BUNNY', 'GRAND CHOCOLATECANDLE', 'ANTIQUE GLASS DRESSING TABLE POT']
# Top 5 recommended items for user 15281.0 : ['JUMBO BAG TOYS', 'CHARLOTTE BAG PINK POLKADOT', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'LUNCH BAG DOLLY GIRL DESIGN', 'RED RETROSPOT CHARLOTTE BAG']
# Top 5 recommended items for user 13001.0 : ['TRAVEL SEWING KIT', 'RIBBON REEL LACE DESIGN', 'RIBBON REEL HEARTS DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'LUNCH BAG SPACEBOY DESIGN']
# Top 5 recommended items for user 13093.0 : ['6 RIBBONS RUSTIC CHARM', 'FROSTED WHITE BASE', 'LUNCH BAG DOLLY GIRL DESIGN', 'TRAVEL SEWING KIT', 'RED RETROSPOT OVEN GLOVE']
# Top 5 recommended items for user 18223.0 : ['JUMBO BAG PINK POLKADOT', 'JUMBO BAG SPACEBOY DESIGN', 'TRAVEL SEWING KIT', 'JUMBO BAG WOODLAND ANIMALS', 'JUMBO BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 13742.0 : ['JUMBO BAG DOLLY GIRL DESIGN', 'STRAWBERRY CHARLOTTE BAG', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG RED RETROSPOT']
# Top 5 recommended items for user 16473.0 : ['FROSTED WHITE BASE', 'SET OF 4 ENGLISH ROSE COASTERS', 'DAISY GARDEN MARKER', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 15093.0 : ['SMALL POPCORN HOLDER', 'JUMBO BAG WOODLAND ANIMALS', 'LUNCH BAG DOLLY GIRL DESIGN', 'SET OF 4 ENGLISH ROSE COASTERS', 'LAVENDER SCENTED FABRIC HEART']
# Top 5 recommended items for user 12921.0 : ['LUNCH BAG WOODLAND', 'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG', 'LUNCH BAG PINK POLKADOT']
# Top 5 recommended items for user 14051.0 : ['CLASSIC METAL BIRDCAGE PLANT HOLDER', 'PORCELAIN ROSE SMALL', 'BOX OF 6 ASSORTED COLOUR TEASPOONS', 'NO JUNK MAIL METAL SIGN', 'PORCELAIN ROSE LARGE']
# Top 5 recommended items for user 14573.0 : ['SET OF 4 ENGLISH ROSE COASTERS', 'LUNCH BAG PINK POLKADOT', 'SET OF 4 NAPKIN CHARMS 3 KEYS', 'ANTIQUE GLASS DRESSING TABLE POT', 'PINK FAIRY CAKE CHILDRENS APRON']
# Top 5 recommended items for user 14532.0 : ['JUMBO STORAGE BAG SKULLS', 'BALLOON ART MAKE YOUR OWN FLOWERS', 'LUNCH BAG SUKI  DESIGN', 'TEA TIME OVEN GLOVE', 'RED RETROSPOT OVEN GLOVE']
# Top 5 recommended items for user 17243.0 : ['HEN HOUSE W CHICK STANDING', 'FOUR HOOK  WHITE LOVEBIRDS', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG PINK VINTAGE PAISLEY', 'STRAWBERRY CHARLOTTE BAG']
# Top 5 recommended items for user 14952.0 : ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG PINK POLKADOT', 'RETROSPOT PARTY BAG + STICKER SET', 'CHARLOTTE BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY']
# Top 5 recommended items for user 16407.0 : ['FROSTED WHITE BASE', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG RED RETROSPOT', 'STRAWBERRY CHARLOTTE BAG', 'LUNCH BAG PINK POLKADOT']
# Top 5 recommended items for user 15738.0 : ['HEN HOUSE W CHICK STANDING', 'JUMBO BAG PINK POLKADOT', 'WATERING CAN GARDEN MARKER', 'SKULL SHOULDER BAG', 'GENTLEMAN SHIRT REPAIR KIT']
# Top 5 recommended items for user 15708.0 : ['STRAWBERRY CHARLOTTE BAG', 'DAISY GARDEN MARKER', 'WATERING CAN GARDEN MARKER', 'JUMBO BAG STRAWBERRY', 'TEA TIME OVEN GLOVE']
# Top 5 recommended items for user 14810.0 : ['JUMBO STORAGE BAG SUKI', 'CHARLOTTE BAG SUKI DESIGN', 'JUMBO BAG TOYS', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 12599.0 : ['CHARLOTTE BAG PINK POLKADOT', 'SMALL HEART MEASURING SPOONS', 'JUMBO BAG SPACEBOY DESIGN', 'MAGIC DRAWING SLATE SPACEBOY', 'DAISY GARDEN MARKER']
# Top 5 recommended items for user 14472.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG CARS BLUE', 'WATERING CAN GARDEN MARKER', 'KITCHEN METAL SIGN', 'NATURAL SLATE RECTANGLE CHALKBOARD']
# Top 5 recommended items for user 16745.0 : ['CHARLOTTE BAG SUKI DESIGN', 'CHARLOTTE BAG PINK POLKADOT', 'STRAWBERRY CHARLOTTE BAG', 'GREEN METAL SWINGING BUNNY', 'DAISY GARDEN MARKER']
# Top 5 recommended items for user 15547.0 : ['LUNCH BAG PINK POLKADOT', 'BALLOON WATER BOMB PACK OF 35', 'KITCHEN METAL SIGN', 'GRAND CHOCOLATECANDLE', 'CERAMIC STRAWBERRY DESIGN MUG']
# Top 5 recommended items for user 12431.0 : ['TRAVEL SEWING KIT', 'CHARLOTTE BAG PINK POLKADOT', 'SKULL SHOULDER BAG', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'RIBBON REEL HEARTS DESIGN']
# Top 5 recommended items for user 17894.0 : ['TRAVEL CARD WALLET KEEP CALM', 'TRAVEL CARD WALLET RETROSPOT', 'BUTTON BOX', 'LUNCH BAG WOODLAND', 'TRAVEL SEWING KIT']
# Top 5 recommended items for user 15996.0 : ['TEA TIME OVEN GLOVE', 'TOILET METAL SIGN', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'RED RETROSPOT SHOPPER BAG', 'RED RETROSPOT WASHBAG']
# Top 5 recommended items for user 17655.0 : ['BALLOON ART MAKE YOUR OWN FLOWERS', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN', 'ETCHED GLASS COASTER', 'PARTY INVITES WOODLAND']
# Top 5 recommended items for user 14211.0 : ['WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN', 'CHARLOTTE BAG DOLLY GIRL DESIGN', 'JUMBO BAG PINK VINTAGE PAISLEY', 'TOY TIDY SPACEBOY']
# Top 5 recommended items for user 15235.0 : ['LUNCH BAG SUKI  DESIGN', 'LUNCH BAG  BLACK SKULL.', 'RETROSPOT PARTY BAG + STICKER SET', 'JUMBO BAG PINK VINTAGE PAISLEY', 'STRAWBERRY CHARLOTTE BAG']
# Top 5 recommended items for user 18283.0 : ['BALLOON ART MAKE YOUR OWN FLOWERS', 'RETROSPOT PARTY BAG + STICKER SET', 'JUMBO BAG WOODLAND ANIMALS', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 13004.0 : ['JUMBO BAG DOLLY GIRL DESIGN', 'SKULL SHOULDER BAG', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG WOODLAND ANIMALS', 'TEA TIME OVEN GLOVE']
# Top 5 recommended items for user 15039.0 : ['RED RETROSPOT CHARLOTTE BAG', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'STRAWBERRY CHARLOTTE BAG']
# Top 5 recommended items for user 12678.0 : ['JUMBO STORAGE BAG SUKI', 'SMALL POPCORN HOLDER', 'LUNCH BAG DOLLY GIRL DESIGN', 'STRAWBERRY BATH SPONGE', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 12464.0 : ['12 PENCILS SMALL TUBE SKULL', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER', 'CHILDS GARDEN FORK BLUE', 'JUMBO STORAGE BAG SKULLS']
# Top 5 recommended items for user 15062.0 : ['WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN', 'TOY TIDY PINK POLKADOT', 'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 15227.0 : ['JUMBO BAG RED RETROSPOT', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG PINK POLKADOT']
# Top 5 recommended items for user 14239.0 : ['JUMBO BAG SPACEBOY DESIGN', 'BUTTON BOX', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 16607.0 : ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO STORAGE BAG SUKI', 'LUNCH BAG SUKI  DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'WATERING CAN GARDEN MARKER']
# Top 5 recommended items for user 16458.0 : ['JUMBO STORAGE BAG SUKI', 'TOY TIDY SPACEBOY', 'SKULL SHOULDER BAG', 'CHARLOTTE BAG SUKI DESIGN', 'RED RETROSPOT WASHBAG']
# Top 5 recommended items for user 17027.0 : ['FROSTED WHITE BASE', 'LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG CARS BLUE', 'PAPER CHAIN KIT EMPIRE', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 14078.0 : ['JUMBO BAG PINK VINTAGE PAISLEY', 'WATERING CAN GARDEN MARKER', 'GENTLEMAN SHIRT REPAIR KIT', 'DAISY GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 12728.0 : ['TRAVEL CARD WALLET KEEP CALM', 'TRAVEL CARD WALLET RETROSPOT', 'WOODLAND CHARLOTTE BAG', 'JUMBO BAG WOODLAND ANIMALS', '12 PENCILS SMALL TUBE SKULL']
# Top 5 recommended items for user 15570.0 : ['TRAVEL SEWING KIT', 'JUMBO BAG SPACEBOY DESIGN', 'RETROSPOT PARTY BAG + STICKER SET', 'CHARLOTTE BAG PINK POLKADOT', 'JUMBO BAG WOODLAND ANIMALS']
# Top 5 recommended items for user 13880.0 : ['JUMBO BAG TOYS', 'SET OF 4 ENGLISH ROSE COASTERS', 'JUMBO BAG STRAWBERRY', 'LUNCH BAG  BLACK SKULL.', 'DOORMAT ENGLISH ROSE']
# Top 5 recommended items for user 17068.0 : ['TRAVEL CARD WALLET KEEP CALM', 'TRAVEL CARD WALLET RETROSPOT', 'TRAVEL CARD WALLET VINTAGE ROSE', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'CHARLOTTE BAG SUKI DESIGN']
# Top 5 recommended items for user 15194.0 : ['TOY TIDY PINK POLKADOT', 'RECYCLING BAG RETROSPOT', 'TOY TIDY SPACEBOY', 'RED RETROSPOT CHARLOTTE BAG', 'RIBBON REEL HEARTS DESIGN']
# Top 5 recommended items for user 18044.0 : ['BUTTON BOX', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'TRAVEL SEWING KIT', 'RED RETROSPOT OVEN GLOVE', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 18075.0 : ['WOODLAND CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO BAG SPACEBOY DESIGN', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'JUMBO BAG PINK POLKADOT']
# Top 5 recommended items for user 12683.0 : ['RED RETROSPOT CHARLOTTE BAG', 'TRAVEL CARD WALLET KEEP CALM', 'TRAVEL CARD WALLET RETROSPOT', 'WOODLAND CHARLOTTE BAG', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 14732.0 : ['JUMBO BAG STRAWBERRY', 'JUMBO BAG DOLLY GIRL DESIGN', 'BUTTON BOX', 'JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 17965.0 : ['LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG SUKI  DESIGN', 'RIBBON REEL LACE DESIGN', 'TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG']
# Top 5 recommended items for user 12709.0 : ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'RECYCLING BAG RETROSPOT', 'JUMBO BAG OWLS', 'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER']
# Top 5 recommended items for user 14506.0 : ['RED RETROSPOT OVEN GLOVE', 'ETCHED GLASS COASTER', 'PARTY INVITES WOODLAND', 'STRAWBERRY BATH SPONGE', 'GRAND CHOCOLATECANDLE']
# Top 5 recommended items for user 15456.0 : ['DOORMAT HEARTS', 'RED RETROSPOT BOWL', 'PINK POLKADOT BOWL', 'DAISY GARDEN MARKER', 'WATERING CAN GARDEN MARKER']
# Top 5 recommended items for user 15660.0 : ['LUNCH BAG SUKI  DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', '12 PENCILS SMALL TUBE SKULL', 'RIDGED GLASS T-LIGHT HOLDER', 'RED RETROSPOT OVEN GLOVE']
# Top 5 recommended items for user 15953.0 : ['CHARLOTTE BAG SUKI DESIGN', 'CHARLOTTE BAG PINK POLKADOT', 'GREEN METAL SWINGING BUNNY', 'RED RETROSPOT APRON', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 16839.0 : ['JUMBO BAG TOYS', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'RED RETROSPOT WASHBAG']
# Top 5 recommended items for user 12747.0 : ['JUMBO BAG TOYS', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'RED RETROSPOT WASHBAG']
# Top 5 recommended items for user 13599.0 : ['LUNCH BAG  BLACK SKULL.', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'STRAWBERRY CHARLOTTE BAG', 'TRAVEL SEWING KIT']
# Top 5 recommended items for user 12352.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'JUMBO STORAGE BAG SUKI', 'SMALL HEART MEASURING SPOONS']
# Top 5 recommended items for user 13110.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'TEA TIME OVEN GLOVE', 'TEA BAG PLATE RED RETROSPOT', 'TOILET METAL SIGN', 'STRAWBERRY CHARLOTTE BAG']
# Top 5 recommended items for user 16525.0 : ['6 RIBBONS RUSTIC CHARM', 'FROSTED WHITE BASE', 'JUMBO BAG PINK POLKADOT', 'TRAVEL SEWING KIT', 'RIBBON REEL LACE DESIGN']
# Top 5 recommended items for user 14560.0 : ['WOODLAND CHARLOTTE BAG', 'JUMBO BAG SPACEBOY DESIGN', 'RED RETROSPOT CHARLOTTE BAG', 'BUTTON BOX', 'JUMBO BAG STRAWBERRY']
# Top 5 recommended items for user 17961.0 : ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'ZINC WILLIE WINKIE  CANDLE STICK', 'LOVE BUILDING BLOCK WORD', 'HANGING FAIRY CAKE DECORATION', 'RED HEART SHAPE LOVE BUCKET']
# Top 5 recommended items for user 15750.0 : ['RIBBON REEL STRIPES DESIGN', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG SCANDINAVIAN PAISLEY', '12 PENCILS SMALL TUBE SKULL', 'ETCHED GLASS COASTER']
# Top 5 recommended items for user 17449.0 : ['WATERING CAN GARDEN MARKER', 'JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SCANDINAVIAN PAISLEY']
# Top 5 recommended items for user 13497.0 : ['DOORMAT RED RETROSPOT', 'JUMBO BAG TOYS', 'SET OF 4 ENGLISH ROSE COASTERS', 'LUNCH BAG SUKI  DESIGN', 'LUNCH BAG  BLACK SKULL.']
# Top 5 recommended items for user 14180.0 : ['SET OF 4 ENGLISH ROSE COASTERS', 'TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG', 'BUTTON BOX', 'S/6 WOODEN SKITTLES IN COTTON BAG']
# Top 5 recommended items for user 12913.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG CARS BLUE', 'LUNCH BAG  BLACK SKULL.', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 18118.0 : ['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI  DESIGN', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG OWLS', 'JUMBO BAG WOODLAND ANIMALS']
# Top 5 recommended items for user 17048.0 : ['WOODLAND CHARLOTTE BAG', 'JUMBO STORAGE BAG SUKI', 'BUTTON BOX', 'RED RETROSPOT CHARLOTTE BAG', 'RIBBON REEL LACE DESIGN']
# Top 5 recommended items for user 16670.0 : ['CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG', 'TRAVEL SEWING KIT', 'STRAWBERRY CHARLOTTE BAG', 'RIBBON REEL HEARTS DESIGN']
# Top 5 recommended items for user 15641.0 : ['BUTTON BOX', 'SKULL SHOULDER BAG', 'JUMBO STORAGE BAG SUKI', '12 PENCILS SMALL TUBE SKULL', 'JUMBO BAG WOODLAND ANIMALS']
# Top 5 recommended items for user 15189.0 : ['TRAVEL SEWING KIT', 'STRAWBERRY SHOPPER BAG', 'LUNCH BAG PINK POLKADOT', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER']
# Top 5 recommended items for user 14657.0 : ['HEN HOUSE W CHICK STANDING', 'SMALL POPCORN HOLDER', 'RIBBON REEL STRIPES DESIGN', 'LUNCH BAG SUKI  DESIGN', 'LUNCH BAG WOODLAND']
# Top 5 recommended items for user 17576.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'JUMBO BAG TOYS', 'CHARLOTTE BAG SUKI DESIGN', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 13230.0 : ['TRAVEL CARD WALLET RETROSPOT', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'LUNCH BAG WOODLAND']
# Top 5 recommended items for user 14388.0 : ['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG WOODLAND', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN', 'STRAWBERRY CHARLOTTE BAG']
# Top 5 recommended items for user 17567.0 : ['SET OF 4 ENGLISH ROSE COASTERS', 'JUMBO BAG PINK POLKADOT', 'CHARLOTTE BAG PINK POLKADOT', 'SKULL SHOULDER BAG', 'JUMBO BAG PINK VINTAGE PAISLEY']
# Top 5 recommended items for user 15304.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'TRAVEL SEWING KIT', 'STRAWBERRY SHOPPER BAG', 'LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT']
# Top 5 recommended items for user 17646.0 : ['WOODLAND CHARLOTTE BAG', 'RIBBON REEL STRIPES DESIGN', 'LUNCH BAG SUKI  DESIGN', 'RECYCLING BAG RETROSPOT', 'JUMBO BAG TOYS']
# Top 5 recommended items for user 12415.0 : ['TRAVEL SEWING KIT', 'BLUE SPOT CERAMIC DRAWER KNOB', 'RED STRIPE CERAMIC DRAWER KNOB', 'RECIPE BOX BLUE SKETCHBOOK DESIGN', 'RETROSPOT RED WASHING UP GLOVES']
# Top 5 recommended items for user 15719.0 : ['JUMBO BAG DOLLY GIRL DESIGN', 'LUNCH BAG SUKI  DESIGN', 'TOY TIDY SPACEBOY', 'SKULL SHOULDER BAG', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 17389.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'JUMBO STORAGE BAG SUKI', 'TRAVEL SEWING KIT']
# Top 5 recommended items for user 12727.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SUKI  DESIGN', 'TRAVEL SEWING KIT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'CHARLOTTE BAG PINK POLKADOT']
# Top 5 recommended items for user 15596.0 : ['SMALL HEART MEASURING SPOONS', 'RETROSPOT PARTY BAG + STICKER SET', 'BUTTON BOX', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG RED RETROSPOT']
# Top 5 recommended items for user 14524.0 : ['LUNCH BAG WOODLAND', 'LUNCH BAG SPACEBOY DESIGN', 'DAISY GARDEN MARKER', 'WATERING CAN GARDEN MARKER', 'BUTTON BOX']
# Top 5 recommended items for user 12417.0 : ['CHARLOTTE BAG PINK POLKADOT', 'TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG', 'BUTTON BOX', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 14057.0 : ['BALLOON WATER BOMB PACK OF 35', '12 COLOURED PARTY BALLOONS', 'VICTORIAN  METAL POSTCARD SPRING', 'WHITE HANGING HEART T-LIGHT HOLDER', 'SMALL RED BABUSHKA NOTEBOOK']
# Top 5 recommended items for user 15005.0 : ['SMALL HEART MEASURING SPOONS', 'SKULL SHOULDER BAG', 'TRAVEL SEWING KIT', 'JUMBO BAG CHARLIE AND LOLA TOYS', '12 PENCILS SMALL TUBE SKULL']
# Top 5 recommended items for user 13959.0 : ['RED RETROSPOT SHOPPER BAG', 'RED RETROSPOT WASHBAG', 'STRAWBERRY SHOPPER BAG', 'WATERING CAN GARDEN MARKER', 'MAGIC DRAWING SLATE SPACEBOY']
# Top 5 recommended items for user 15611.0 : ['STRAWBERRY   PICNIC BAG', 'TRAVEL SEWING KIT', 'LUNCH BAG CARS BLUE', 'BUTTON BOX', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 14702.0 : ['FROSTED WHITE BASE', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT']
# Top 5 recommended items for user 13715.0 : ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG WOODLAND ANIMALS', 'JUMBO BAG DOLLY GIRL DESIGN', 'LUNCH BAG SUKI  DESIGN', 'SKULL SHOULDER BAG']
# Top 5 recommended items for user 12553.0 : ['RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL CHRISTMAS PRESENT', 'RIBBON REEL MAKING SNOWMEN', 'STRAWBERRY   PICNIC BAG', 'JUMBO BAG PINK POLKADOT']
# Top 5 recommended items for user 17001.0 : ['12 COLOURED PARTY BALLOONS', '6 ROCKET BALLOONS', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'RECYCLING BAG RETROSPOT', 'JUMBO BAG OWLS']
# Top 5 recommended items for user 17581.0 : ['JUMBO STORAGE BAG SUKI', 'RED RETROSPOT WASHBAG', 'JUMBO BAG DOLLY GIRL DESIGN', 'CHARLOTTE BAG SUKI DESIGN', 'JUMBO BAG TOYS']
# Top 5 recommended items for user 15827.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'JUMBO BAG SPACEBOY DESIGN', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG OWLS']
# Top 5 recommended items for user 14466.0 : ['JUMBO BAG TOYS', 'JUMBO BAG PINK VINTAGE PAISLEY', 'TRAVEL SEWING KIT', 'RETROSPOT PARTY BAG + STICKER SET', 'JUMBO BAG PINK POLKADOT']
# Top 5 recommended items for user 15514.0 : ['GENTLEMAN SHIRT REPAIR KIT', '12 PENCILS SMALL TUBE SKULL', 'ETCHED GLASS COASTER', 'PARTY INVITES WOODLAND', 'BALLOON WATER BOMB PACK OF 35']
# Top 5 recommended items for user 14779.0 : ['TRAVEL SEWING KIT', 'RED RETROSPOT CHARLOTTE BAG', 'STRAWBERRY SHOPPER BAG', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER']
# Top 5 recommended items for user 17191.0 : ['DOORMAT RED RETROSPOT', 'TOILET METAL SIGN', 'GENTLEMAN SHIRT REPAIR KIT', 'LUNCH BAG PINK POLKADOT', 'BALLOON WATER BOMB PACK OF 35']
# Top 5 recommended items for user 15358.0 : ['TRAVEL SEWING KIT', 'JUMBO BAG SPACEBOY DESIGN', 'WATERING CAN GARDEN MARKER', 'DOORMAT ENGLISH ROSE', 'LUNCH BAG SUKI  DESIGN']
# Top 5 recommended items for user 13491.0 : ['JUMBO BAG PINK POLKADOT', 'SKULL SHOULDER BAG', 'CHARLOTTE BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 14031.0 : ['JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY', 'LUNCH BAG WOODLAND']
# Top 5 recommended items for user 15034.0 : ['LUNCH BAG SUKI  DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', '12 PENCILS SMALL TUBE SKULL', 'RIDGED GLASS T-LIGHT HOLDER', 'STRAWBERRY BATH SPONGE']
# Top 5 recommended items for user 16923.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG RED RETROSPOT', 'JUMBO BAG RED RETROSPOT', 'STRAWBERRY CHARLOTTE BAG']
# Top 5 recommended items for user 14701.0 : ['RED RETROSPOT OVEN GLOVE', 'PACK OF 12 STICKY BUNNIES', 'CERAMIC STRAWBERRY DESIGN MUG', 'TRAVEL CARD WALLET RETROSPOT', 'SMALL GLASS HEART TRINKET POT']
# Top 5 recommended items for user 17769.0 : ['TRAVEL CARD WALLET RETROSPOT', 'JUMBO BAG PINK VINTAGE PAISLEY', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN', 'RED RETROSPOT OVEN GLOVE']
# Top 5 recommended items for user 16033.0 : ['12 COLOURED PARTY BALLOONS', '6 ROCKET BALLOONS', 'LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG CARS BLUE', 'RED RETROSPOT CHARLOTTE BAG']
# Top 5 recommended items for user 13263.0 : ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'TEA TIME OVEN GLOVE', 'STRAWBERRY SHOPPER BAG', 'MAGIC DRAWING SLATE SPACEBOY', 'WATERING CAN GARDEN MARKER']
# Top 5 recommended items for user 14161.0 : ['TEA TIME PARTY BUNTING', 'GRAND CHOCOLATECANDLE', 'MINI CAKE STAND WITH HANGING CAKES', 'NUMBER TILE COTTAGE GARDEN 4', 'NUMBER TILE COTTAGE GARDEN 2']
# Top 5 recommended items for user 15696.0 : ['WATERING CAN GARDEN MARKER', '12 PENCILS SMALL TUBE SKULL', 'SET OF 4 NAPKIN CHARMS 3 KEYS', 'STRAWBERRY FAIRY CAKE TEAPOT', 'CHILLI LIGHTS']
# Top 5 recommended items for user 12712.0 : ['JUMBO BAG STRAWBERRY', 'STRAWBERRY CHARLOTTE BAG', 'JUMBO BAG DOLLY GIRL DESIGN', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT']
# Top 5 recommended items for user 13881.0 : ['JUMBO STORAGE BAG SKULLS', '6 RIBBONS RUSTIC CHARM', 'FROSTED WHITE BASE', 'JUMBO BAG PINK POLKADOT', 'LUNCH BAG DOLLY GIRL DESIGN']
# Top 5 recommended items for user 12708.0 : ['RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'SMALL HEART MEASURING SPOONS', 'TRAVEL SEWING KIT', 'BUTTON BOX']
# Top 5 recommended items for user 13117.0 : ['BALLOON ART MAKE YOUR OWN FLOWERS', 'LUNCH BAG SUKI  DESIGN', 'WATERING CAN GARDEN MARKER', 'MAGIC DRAWING SLATE SPACEBOY', 'DAISY GARDEN MARKER']
# Top 5 recommended items for user 16316.0 : ['RED RETROSPOT CHARLOTTE BAG', 'JUMBO STORAGE BAG SUKI', 'STRAWBERRY SHOPPER BAG', 'LUNCH BAG RED RETROSPOT', 'JUMBO BAG TOYS']
# Top 5 recommended items for user 13408.0 : ['JUMBO BAG TOYS', 'JUMBO BAG PINK VINTAGE PAISLEY', 'TRAVEL SEWING KIT', 'BALLOON ART MAKE YOUR OWN FLOWERS', 'LUNCH BAG  BLACK SKULL.']
# Top 5 recommended items for user 17696.0 : ['JUMBO STORAGE BAG SUKI', 'BUTTON BOX', 'JUMBO BAG DOLLY GIRL DESIGN', 'JUMBO BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG']
# Top 5 recommended items for user 17634.0 : ['RECYCLING BAG RETROSPOT', 'RED KITCHEN SCALES', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG SPACEBOY DESIGN', 'BALLOON WATER BOMB PACK OF 35']
# Top 5 recommended items for user 15498.0 : ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 12754.0 : ['GENTLEMAN SHIRT REPAIR KIT', 'CHARLOTTE BAG PINK POLKADOT', 'DAISY GARDEN MARKER', 'RIDGED GLASS T-LIGHT HOLDER', 'DOORMAT FANCY FONT HOME SWEET HOME']
# Top 5 recommended items for user 15290.0 : ['6 RIBBONS RUSTIC CHARM', 'FROSTED WHITE BASE', 'JUMBO BAG WOODLAND ANIMALS', 'WOODLAND CHARLOTTE BAG', 'RIBBON REEL STRIPES DESIGN']
# Top 5 recommended items for user 17162.0 : ['WOODLAND CHARLOTTE BAG', 'NO JUNK MAIL METAL SIGN', 'LUNCH BAG  BLACK SKULL.', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 15752.0 : ['LUNCH BAG SUKI  DESIGN', 'CHARLOTTE BAG SUKI DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'DAISY GARDEN MARKER', 'WATERING CAN GARDEN MARKER']
# Top 5 recommended items for user 13092.0 : ['ETCHED GLASS COASTER', 'PARTY INVITES WOODLAND', 'BALLOON WATER BOMB PACK OF 35', 'GRAND CHOCOLATECANDLE', 'PACK OF 12 STICKY BUNNIES']
# Top 5 recommended items for user 13798.0 : ['JUMBO STORAGE BAG SKULLS', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'JUMBO  BAG BAROQUE BLACK WHITE']
# Top 5 recommended items for user 16782.0 : ['CHARLOTTE BAG PINK POLKADOT', 'RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'RED RETROSPOT WASHBAG', 'JUMBO BAG SCANDINAVIAN PAISLEY']
# Top 5 recommended items for user 14709.0 : ['TEA TIME PARTY BUNTING', 'LUNCH BAG WOODLAND', 'LUNCH BAG CARS BLUE', 'RIBBON REEL STRIPES DESIGN', 'JUMBO BAG PINK POLKADOT']
# Top 5 recommended items for user 16779.0 : ['RIBBON REEL HEARTS DESIGN', 'RIBBON REEL LACE DESIGN', 'RED RETROSPOT WASHBAG', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'STRAWBERRY SHOPPER BAG']
# Top 5 recommended items for user 17419.0 : ['DAISY GARDEN MARKER', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'LUNCH BAG PINK POLKADOT']
# Top 5 recommended items for user 12528.0 : ['JUMBO BAG SPACEBOY DESIGN', 'RED RETROSPOT PEG BAG', 'BLUE POLKADOT BOWL', 'RED RETROSPOT BOWL', 'PINK POLKADOT BOWL']
# Top 5 recommended items for user 16710.0 : ['TRAVEL CARD WALLET RETROSPOT', 'LUNCH BAG WOODLAND', 'TRAVEL SEWING KIT', 'STRAWBERRY SHOPPER BAG', 'LUNCH BAG PINK POLKADOT']
# Top 5 recommended items for user 12662.0 : ['TOY TIDY SPACEBOY', 'RED RETROSPOT PEG BAG', 'CHARLOTTE BAG SUKI DESIGN', 'LUNCH BAG  BLACK SKULL.', 'JUMBO STORAGE BAG SUKI']
# Top 5 recommended items for user 16927.0 : ['HEN HOUSE W CHICK STANDING', 'JUMBO STORAGE BAG SKULLS', 'JUMBO BAG SPACEBOY DESIGN', '6 RIBBONS RUSTIC CHARM', 'FROSTED WHITE BASE']
# Top 5 recommended items for user 13777.0 : ['JUMBO  BAG BAROQUE BLACK WHITE', 'LUNCH BAG SUKI  DESIGN', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SPACEBOY DESIGN', 'JUMBO SHOPPER VINTAGE RED PAISLEY']
# Top 5 recommended items for user 15023.0 : ['TEA TIME PARTY BUNTING', 'WATERING CAN GARDEN MARKER', 'LUNCH BAG SUKI  DESIGN', 'CHILLI LIGHTS', 'FOLDING UMBRELLA BLACKBLUE POLKADOT']
# Top 5 recommended items for user 14426.0 : ['BALLOON ART MAKE YOUR OWN FLOWERS', 'LUNCH BAG SUKI  DESIGN', 'JUMBO BAG PINK POLKADOT', 'RIBBON REEL LACE DESIGN', 'TRAVEL SEWING KIT']
# Top 5 recommended items for user 13267.0 : ['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG CARS BLUE', 'RED RETROSPOT CHARLOTTE BAG', 'JUMBO  BAG BAROQUE BLACK WHITE', 'STRAWBERRY CHARLOTTE BAG']
# Top 5 recommended items for user 14032.0 : ['JUMBO BAG WOODLAND ANIMALS', 'WOODLAND CHARLOTTE BAG', 'JUMBO STORAGE BAG SUKI', 'CHARLOTTE BAG SUKI DESIGN', 'FRENCH BLUE METAL DOOR SIGN 2']
# Top 5 recommended items for user 12924.0 : ['LUNCH BAG CARS BLUE', 'TEA TIME OVEN GLOVE', 'JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG RED RETROSPOT']
# Top 5 recommended items for user 14825.0 : ['TOILET METAL SIGN', 'FROSTED WHITE BASE', 'RIBBON REEL STRIPES DESIGN', 'RECYCLING BAG RETROSPOT', 'ETCHED GLASS COASTER']
# Top 5 recommended items for user 16221.0 : ['RETROSPOT PARTY BAG + STICKER SET', 'TRAVEL SEWING KIT', 'SET OF 3 BUTTERFLY COOKIE CUTTERS', 'SET OF 4 NAPKIN CHARMS 3 KEYS', 'GRAND CHOCOLATECANDLE']
# Top 5 recommended items for user 14534.0 : ['WOODLAND CHARLOTTE BAG', 'EDWARDIAN PARASOL BLACK', 'HEN HOUSE W CHICK STANDING', '12 COLOURED PARTY BALLOONS', 'JUMBO SHOPPER VINTAGE RED PAISLEY']

# %% [markdown]
# ## Evaluation

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5112 entries, 0 to 9982
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Itemname    5112 non-null   object
#  1   Quantity    5112 non-null   float64
#  2   CustomerID  5112 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 159.8+ KB

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10140 entries, 61 to 39999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Itemname    10140 non-null  object
#  1   Quantity    10140 non-null  int64
#  2   CustomerID  10140 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 316.9+ KB

# %%
def evaluate_recommendations(recommendations, test_data):
    total_correct_predictions = 0
    total_predictions = 0

    for user_id, row in recommendations.iterrows():
        recommended_items = row['Top_Items']
        actual_items = test_data[test_data['CustomerID'] == user_id]['Itemname'].tolist()
        
        # print("User ID:", user_id)
        # print("Actual Items:", actual_items)
        # print("Recommended Items:", recommended_items)

        correct_predictions = len(set(recommended_items) & set(actual_items))
        
        total_correct_predictions += correct_predictions
        total_predictions += len(recommended_items)
    
    accuracy = total_correct_predictions / total_predictions
    return accuracy

# 调用评估函数
accuracy = evaluate_recommendations(test_recommendations, test_data)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.0

# %%
test_recommendations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 15311.0 to 14534.0
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Top_Items  250 non-null    object
# dtypes: object(1)
# memory usage: 12.0+ KB

# %%
def compute_precision(test_set, recommendations):
    total_users = len(test_set)
    correct_predictions = 0
    
    for user_id in test_set.index:
        actual_items = test_set.loc[user_id, 'Itemname']  # 假设 'Itemname' 列包含实际物品
        
        recommended_items = recommendations.loc[user_id, 'Top_Items']
        
        # 计算推荐物品与实际物品的交集数量
        intersection = len(set(actual_items) & set(recommended_items))
        
        # 更新正确预测的数量
        correct_predictions += intersection
        
    # 计算准确率
    precision = correct_predictions / (total_users * len(recommended_items))
    
    return precision

# 计算准确率
precision = compute_precision(test_data, test_recommendations)
print("Precision:", precision)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb Cell 70 line 2
#      <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=19'>20</a>     return precision
#      <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=21'>22</a> # 计算准确率
# ---> <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=22'>23</a> precision = compute_precision(test_data, test_recommendations)
#      <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=23'>24</a> print("Precision:", precision)
#
# /Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb Cell 70 line 1
#      <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=14'>15</a>     correct_predictions += intersection
#      <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=16'>17</a> # 计算准确率
# ---> <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=17'>18</a> precision = correct_predictions / (total_users * len(recommended_items))
#      <a href='vscode-notebook-cell:/Users/yuqing/Desktop/MiningBigData/assignment3/a1841612_assign2.ipynb#Y216sZmlsZQ%3D%3D?line=19'>20</a> return precision
#
# ZeroDivisionError: division by zero
